# %% [markdown]
# # Agenda
# ![Alt text]('C:/Users/dylan/Documents/GitHub/Solana-Bootcamp/Picture/agenda_1.png')

# %%
from IPython.display import Image
Image(filename='C:/Users/dylan/Documents/GitHub/Solana-Bootcamp/Picture/agenda_1.png')

# %% [markdown]
# # Solana Technical Advantage:
#
# - Fast confirmation time
# - Low Transaction fees
# - All while maintaining consensus across 2500+ validators
# - Terrible MEV-protection
# - Firedancer will make things faster
#
# https://www.youtube.com/watch?v=0P8JeL3TURU

# %% [markdown]
# # How it works

# %%
from IPython.display import Image
Image(filename='C:/Users/dylan/Documents/GitHub/Solana-Bootcamp/Picture/How_transaction_work.png')

# %% [markdown]
# - Leader get all transaction, pack them into a block
# - Send them all over the world, 2500++ voting using turbine - block propagation of solana protocol
# - Most transactions can be ran in parallel because every transaction is actually stateless
